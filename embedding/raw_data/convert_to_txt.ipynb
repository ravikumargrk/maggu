# %% [markdown]
# ### Constants

# %%
# content directory
# content\{idx}_{filename}.html

# images directory
# images\{idx}_{filename}.jpg

# meta data 
# DMAS_TOC_MAP.json 

# iterate recursively through TOC MAP 
# for each item, 

# should connect document to other documents (later, also its images)
# dict['html_filename', 'url', 'children':[page_nums], 'images:':[]]

# document id used in TRC
DOC_ID = 'ezXh6dvgLV1nzevBm9aHDA'

# %% [markdown]
# ### Building Page Meta (without images part)

# %%
import os 
flattened_document_meta = []
def extract_document_info(document_toc_array:list[dict]):
    # url_ = f'https://trc-techresource.mastercard.com/r/{DOC_ID}/{content_info['tocId']}'
    document_idx_array = []

    for document_meta in document_toc_array:
        document_idx = len(flattened_document_meta)
        flattened_document_meta.append(
            {
                'page_idx' : document_idx,
                'title': document_meta['title'],
                'filename' : os.path.basename(document_meta['prettyUrl']),
                'url': f'https://trc-techresource.mastercard.com/r/{DOC_ID}/{document_meta["tocId"]}',
                'children': extract_document_info(document_meta['children'])
            }
        )
        document_idx_array.append(document_idx)
    return document_idx_array

# %%
import json
with open('DMAS_TOC_MAP.json') as f:
    toc_meta = json.load(f)
    
flattened_document_meta = []
_ = extract_document_info(toc_meta)

# %%
flattened_document_meta
# Out:
# [{'page_idx': 0,
#   'title': 'Mastercard Network Processing Dual Message Authorization System Guide',
#   'filename': 'fql1729791739642.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/3zTtbwzpjdpdCQGa_JAHNg',
#   'children': []},
#  {'page_idx': 1,
#   'title': 'How to use this guide',
#   'filename': 'kwn1724863424441.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/V~ItyuIWcR_n93UdP2RTjQ',
#   'children': []},
#  {'page_idx': 2,
#   'title': 'Introduction to Mastercard switches for processing',
#   'filename': 'nze1724869144978.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JFsYQABhOjdzkRTN12wEww',
#   'children': []},
#  {'page_idx': 3,
#   'title': 'Introduction to Mastercard Dual Message Authorization System processing',
#   'filename': 'iki1724869178217.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/YJX2Je9ED2GFq2YOqlC5xg',
#   'children': []},
#  {'page_idx': 4,
#   'title': 'Dual Message Authorization System features',
#   'filename': 'zgd1724869275829.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/sbCBp6xPt9ry_A6V78rXgg',
#   'children': []},
#  {'page_idx': 5,
#   'title': 'Participants in Mastercard Network processing',
#   'filename': 'bml1724869339811.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/rIo~NFtCiGaPK5tFtd3qKw',
#   'children': []},
#  {'page_idx': 6,
#   'title': 'Dual Message Authorization System basics',
#   'filename': 'vep1724869573670.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/XY9GMA_R~5~bgLB~K8wzQA',
#   'children': []},
#  {'page_idx': 2,
#   'title': 'High-level overview',
#   'filename': 'sso1724864208679.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Mm0_zdCWrJjIYZ8sat~OHQ',
#   'children': [2, 3, 4, 5, 6]},
#  {'page_idx': 8,
#   'title': 'Mastercard message classifications',
#   'filename': 'vqg1725897069490.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/p8mQlqcoCkqBIIPX4_jpgw',
#   'children': []},
#  {'page_idx': 9,
#   'title': 'List of Dual Message Authorization System MTIs',
#   'filename': 'vyl1623207174376.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/sF2SgNqRxGznB6hp1VihKA',
#   'children': []},
#  {'page_idx': 10,
#   'title': 'Authorization/01xx messages',
#   'filename': 'umt1717012679629.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/iRJv_pbowRGh0z6682MO3w',
#   'children': []},
#  {'page_idx': 11,
#   'title': 'Issuer File Update/03xx messages',
#   'filename': 'bzl1717031864886.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/2jLcJk9eHqPeWvj091nCAQ',
#   'children': []},
#  {'page_idx': 12,
#   'title': 'Reversal/04xx messages',
#   'filename': 'cvx1717035179055.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Gt1_HXLjfFNwB4QaPrO~yw',
#   'children': []},
#  {'page_idx': 13,
#   'title': 'Administrative/06xx messages',
#   'filename': 'xmq1717036276162.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/23izC1D86seQfP~UWuyu6w',
#   'children': []},
#  {'page_idx': 14,
#   'title': 'Network Management/08xx messages',
#   'filename': 'rdt1717282831422.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/PNOyH~NEaO6viVqc5JA_UQ',
#   'children': []},
#  {'page_idx': 10,
#   'title': 'About message definitions',
#   'filename': 'ntj1725898097913.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Z_M9VKQh97tBaST~Op0rHQ',
#   'children': [10, 11, 12, 13, 14]},
#  {'page_idx': 16,
#   'title': 'Request Failure from acquirer host to acquirer MIP',
#   'filename': 'zip1725990105357.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bUbUc2085om4raXqeTZLPw',
#   'children': []},
#  {'page_idx': 17,
#   'title': 'Request Failure from acquirer MIP to Mastercard Network',
#   'filename': 'ske1726002474321.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Q8WJn5YLSRvU0~Jo7nLDJA',
#   'children': []},
#  {'page_idx': 18,
#   'title': 'Request Failure from Mastercard Network to issuer MIP',
#   'filename': 'fwx1726003288061.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/w5S20B5bDEN96RpMIXc0WA',
#   'children': []},
#  {'page_idx': 19,
#   'title': 'Request Failure from issuer MIP to issuer host',
#   'filename': 'nww1726004286059.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/LGQshOc_OCU05fTDGEs_Yg',
#   'children': []},
#  {'page_idx': 20,
#   'title': 'Response Failure from issuer host to issuer MIP',
#   'filename': 'mzk1726005597044.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/c_knfsmiZe92D7RuQSWufg',
#   'children': []},
#  {'page_idx': 21,
#   'title': 'Response Failure from issuer MIP to Mastercard Network',
#   'filename': 'dyk1726011212193.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/gYqKaW_bH24TzitjSBwqDw',
#   'children': []},
#  {'page_idx': 22,
#   'title': 'Response Failure from Mastercard Network to acquirer MIP',
#   'filename': 'hpg1726015210926.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/FGR9t7UQ0LUW7iB63e2~lw',
#   'children': []},
#  {'page_idx': 23,
#   'title': 'Response Failure from acquirer MIP to acquirer host',
#   'filename': 'dxs1726015889703.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lv797vb2Ijsq_LJUnHBv8w',
#   'children': []},
#  {'page_idx': 16,
#   'title': 'Failure scenarios: communication-related flows',
#   'filename': 'zqd1726018123773.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/T6GvtDIIkXZyl4aqFyz_0w',
#   'children': [16, 17, 18, 19, 20, 21, 22, 23]},
#  {'page_idx': 25,
#   'title': 'Response from issuer contains errors',
#   'filename': 'eyh1726018940108.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/w1z_sOS6sUnQBv32kLK_tw',
#   'children': []},
#  {'page_idx': 26,
#   'title': 'Issuer response received late (after time limit)',
#   'filename': 'nma1726019746628.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/egmaHsS3IACigaXkoivx3w',
#   'children': []},
#  {'page_idx': 25,
#   'title': 'Failure scenarios: issuer response contains errors or late response flow',
#   'filename': 'fvi1726018544730.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/9ZNdPWKOvmO_su8XE~QHhA',
#   'children': [25, 26]},
#  {'page_idx': 28,
#   'title': 'Communication Failure or primary issuer not signed in',
#   'filename': 'woy1726021025104.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/G4w1qfy6IM~YFpLSVlKoqA',
#   'children': []},
#  {'page_idx': 29,
#   'title': 'Primary issuer times out',
#   'filename': 'nyu1623207179946.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/cx7Nsl6tU5u63XR69ObSLA',
#   'children': []},
#  {'page_idx': 30,
#   'title': 'Primary issuer responds after time limit and primary issuer response received first',
#   'filename': 'vho1623207180108.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vRruD~n2ISzfehr1mZHNBg',
#   'children': []},
#  {'page_idx': 28,
#   'title': 'Failure scenarios: alternate issuer host configuration flows',
#   'filename': 'dsb1726020650492.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4eYqKqMCuSCT4~pqWKEfMQ',
#   'children': [28, 29, 30]},
#  {'page_idx': 32,
#   'title': 'No alternate processing, issuer late response or not in time limit',
#   'filename': 'gbj1623207178360.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/_vlAs65Nu9X5cXZ7doL1fA',
#   'children': []},
#  {'page_idx': 33,
#   'title': 'No alternate processing, issuer response contains errors',
#   'filename': 'mpw1726024251698.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JwV2ueToR~PkO0gByvAHVg',
#   'children': []},
#  {'page_idx': 32,
#   'title': 'Failure scenarios: no alternate processing allowed',
#   'filename': 'ikc1726023556801.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/k6OEGsdSgSxgv0mIMB2Dlw',
#   'children': [32, 33]},
#  {'page_idx': 35,
#   'title': 'Acquirer-generated Authorization Advice message',
#   'filename': 'icc1623207179234.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/tEF7_awxiIX2kN8KxgWgCA',
#   'children': []},
#  {'page_idx': 36,
#   'title': 'Acquirer-generated Advice message, issuer not available',
#   'filename': 'iff1623207179316.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/1SoTOLVd0vcPUA1O~BMKkg',
#   'children': []},
#  {'page_idx': 37,
#   'title': 'System-generated Authorization Advice message',
#   'filename': 'mik1726026087207.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/shvOzS74SU9mv0EawhgYkA',
#   'children': []},
#  {'page_idx': 35,
#   'title': 'Authorization Advice messages',
#   'filename': 'qms1726025053777.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/s2KH6C5l6QD5rBJ1lIeO6g',
#   'children': [35, 36, 37]},
#  {'page_idx': 39,
#   'title': 'Standard Reversal Request',
#   'filename': 'bqg1623207180489.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/XcSDzSURK7Dn6JxqehTH7w',
#   'children': []},
#  {'page_idx': 40,
#   'title': 'Reversal Response message failed at acquirer',
#   'filename': 'pai1726026927890.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/yGnbTp9pFsWwbsFQKNUSkQ',
#   'children': []},
#  {'page_idx': 41,
#   'title': 'Reversal Request not delivered to issuer or issuer signed out',
#   'filename': 'rcs1623207180896.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lEmwf7eZuqKTMYY22hhU~A',
#   'children': []},
#  {'page_idx': 42,
#   'title': 'Reversal Request no response from issuer or not within time limit',
#   'filename': 'fli1623207180582.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/wFt2H0OJ3bmKG6DOdPAe6Q',
#   'children': []},
#  {'page_idx': 43,
#   'title': 'Reversal Request late response from issuer',
#   'filename': 'tnq1623207180665.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Pt8dEeIr9xtdpoVuRABeAQ',
#   'children': []},
#  {'page_idx': 44,
#   'title': 'Reversal Request response from issuer contains errors',
#   'filename': 'zrx1623207180817.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/A6g24uxOKJwYzkFwYqKnfQ',
#   'children': []},
#  {'page_idx': 45,
#   'title': 'System-generated Reversal Advice',
#   'filename': 'lsb1726028155491.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/SmsfulzxLNLW~QArfnqnSw',
#   'children': []},
#  {'page_idx': 39,
#   'title': 'Reversal Request and Advice messages',
#   'filename': 'wfy1726026523028.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/tbyGgy0wCKYvov9bTa7KRQ',
#   'children': [39, 40, 41, 42, 43, 44, 45]},
#  {'page_idx': 16,
#   'title': 'Standard flow',
#   'filename': 'mos1725987254710.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/dAQp0h3zMjohDvlmBntOHA',
#   'children': [16, 25, 28, 32, 35, 39]},
#  {'page_idx': 48,
#   'title': 'Authorization Request: Account Status Inquiry',
#   'filename': 'nud1726029337018.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/7dn04zV11iWSsodcrkFjzA',
#   'children': []},
#  {'page_idx': 49,
#   'title': 'Authorization Request: Mastercard Digital Enablement Service (MDES) pre-digitization',
#   'filename': 'rhz1726029648641.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/IESlPfggLw2_jWBxasFr3Q',
#   'children': []},
#  {'page_idx': 50,
#   'title': 'Standard Chip-PIN Management request',
#   'filename': 'knx1623207178601.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JFeAJXtsHCEXNE1UL2jBLg',
#   'children': []},
#  {'page_idx': 51,
#   'title': 'Chip-PIN Management Request failure from acquirer',
#   'filename': 'cgb1623207178906.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/irnOdQAss1Armpw9UIDYxw',
#   'children': []},
#  {'page_idx': 52,
#   'title': 'Chip-PIN Management Response cannot be delivered to the acquirer',
#   'filename': 'jzd1623207178985.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/_PZav1om02NldT41v2hY0A',
#   'children': []},
#  {'page_idx': 53,
#   'title': 'Chip-PIN Management Update cannot be transmitted or applied to chip card',
#   'filename': 'xwb1623207178680.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/~uafn4b4FbtN46yPxfw38g',
#   'children': []},
#  {'page_idx': 54,
#   'title': 'Chip-PIN Management Request unable to connect to issuer',
#   'filename': 'yrf1623207178760.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bRCwl0oubZjDtQ~GvVQzjQ',
#   'children': []},
#  {'page_idx': 55,
#   'title': 'PIN-management Response not received from issuer',
#   'filename': 'tcg1623207178840.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/0vVhYgFwROsju~cxHPxJcQ',
#   'children': []},
#  {'page_idx': 50,
#   'title': 'Authorization Request: Chip-PIN Management',
#   'filename': 'kdq1726030595120.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/_rU0z9xE1RCUF8jfQdimtg',
#   'children': [50, 51, 52, 53, 54, 55]},
#  {'page_idx': 57,
#   'title': 'Authorization Response Acknowledgment/0180',
#   'filename': 'oor1623207179635.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/L4_qO6DQ6pQvAroCSd8Xag',
#   'children': []},
#  {'page_idx': 48,
#   'title': 'Non-financial transaction function flows',
#   'filename': 'sid1726028934771.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/9f5HknlHAs~sTyEgDC3iiA',
#   'children': [48, 49, 50, 57]},
#  {'page_idx': 59,
#   'title': 'Issuer File Update Requests',
#   'filename': 'can1623207180330.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/EUIRU76NiLhmD_xx0wCfuQ',
#   'children': []},
#  {'page_idx': 60,
#   'title': 'Standard Administrative Request',
#   'filename': 'eqs1623207181135.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/8nZ~olwaiBJjL75Bv_CfHw',
#   'children': []},
#  {'page_idx': 61,
#   'title': 'Acquirer-edit Failure',
#   'filename': 'vqt1623207181202.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/x150Q4U5UIEYI01f~Oa8Ew',
#   'children': []},
#  {'page_idx': 62,
#   'title': 'Communication Failure at issuer',
#   'filename': 'qnl1623207181281.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ZbDToI9FDkhiuAwMC6qYaw',
#   'children': []},
#  {'page_idx': 63,
#   'title': 'Communication Failure at acquirer',
#   'filename': 'jkt1623207181360.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ghkm7clafJ1lMxJbVfuRmQ',
#   'children': []},
#  {'page_idx': 64,
#   'title': 'Late or no issuer response',
#   'filename': 'ply1623207181537.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Rk9m2J87NAcLYI27yOFTRw',
#   'children': []},
#  {'page_idx': 65,
#   'title': 'Issuer-edit Failure',
#   'filename': 'nxw1623207181618.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lwnmBdWD2jlsitr4CRxmUQ',
#   'children': []},
#  {'page_idx': 60,
#   'title': 'Administrative Request messages',
#   'filename': 'skm1726062650619.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/_tWggFd3BbaUNeTwiBrBTw',
#   'children': [60, 61, 62, 63, 64, 65]},
#  {'page_idx': 67,
#   'title': 'Standard Administrative Advice',
#   'filename': 'lxg1623207181697.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/wHxbZ_GJC_~d_yPNvB1ryg',
#   'children': []},
#  {'page_idx': 68,
#   'title': 'Failure scenario: Administrative Advice for invalid message',
#   'filename': 'zsw1623207181778.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/AF0~eHfPsAtkxYvzhtdSFQ',
#   'children': []},
#  {'page_idx': 69,
#   'title': 'MDES-notification advice',
#   'filename': 'atr1726065215265.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/gQAlTIjEW4VWedjs8j4jAg',
#   'children': []},
#  {'page_idx': 67,
#   'title': 'Administrative Advice messages',
#   'filename': 'zmc1726064521323.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JIA5BhjTg1_FXmzl_ILI3A',
#   'children': [67, 68, 69]},
#  {'page_idx': 71,
#   'title': 'Network sign-on or sign-off',
#   'filename': 'uho1623207181842.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ohr5ZmZzGW_x0PIrrctkag',
#   'children': []},
#  {'page_idx': 72,
#   'title': 'Request for issuer-generated or solicited SAF',
#   'filename': 'igw1623207181923.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/UhxOOCmlnKF~ZszLCXwKuQ',
#   'children': []},
#  {'page_idx': 73,
#   'title': 'Unsolicited SAF after sign-on',
#   'filename': 'wzt1623207182005.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Hd4aL9KcxjweO3Fs8hU07A',
#   'children': []},
#  {'page_idx': 74,
#   'title': 'Network-connection status request: customer-generated',
#   'filename': 'wni1623207182084.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/yuGv5Z23sKYZlV5Boc0TzA',
#   'children': []},
#  {'page_idx': 75,
#   'title': 'Network-connection status request: system-generated',
#   'filename': 'jhg1623207182169.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/8h~~G6qiuuV1~nD_7V1G9w',
#   'children': []},
#  {'page_idx': 76,
#   'title': 'Host activation or deactivation',
#   'filename': 'vkq1623207182249.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/9mJWFSEcpRcOtPRD5GL9Hw',
#   'children': []},
#  {'page_idx': 77,
#   'title': 'PIN Encryption Key exchange request: customer generated',
#   'filename': 'ieo1623207182410.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JH3Z373u8L4O_9Sq7hETYw',
#   'children': []},
#  {'page_idx': 78,
#   'title': 'PEK-exchange request: system generated',
#   'filename': 'hox1623207182330.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/p_TF2wQv6nv~2ogNI9~MQA',
#   'children': []},
#  {'page_idx': 71,
#   'title': 'Network management requests',
#   'filename': 'vnf1726066051956.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/90TFs5aKVil47AUc1YYu1Q',
#   'children': [71, 72, 73, 74, 75, 76, 77, 78]},
#  {'page_idx': 59,
#   'title': 'Supporting transaction function flows',
#   'filename': 'osm1726032210165.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/v6VzwQ8x79~RlcsvhjyKZg',
#   'children': [59, 60, 67, 71]},
#  {'page_idx': 16,
#   'title': 'Message flows',
#   'filename': 'eyu1725987198407.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/CXDo15SGnsauB4f5RhFN0Q',
#   'children': [16, 48, 59]},
#  {'page_idx': 8,
#   'title': 'Introduction to messages',
#   'filename': 'tzd1716487611502.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/DMeRAVdZwCLw0s1DThfwTQ',
#   'children': [8, 9, 10, 16]},
#  {'page_idx': 83,
#   'title': 'Data representation',
#   'filename': 'pas1614570857999.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/AlkIO4o~TWoZFSTcdaqoUA',
#   'children': []},
#  {'page_idx': 84,
#   'title': 'Data length',
#   'filename': 'ufv1614570858217.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4dEnop3ivRGYcJfjic4D8A',
#   'children': []},
#  {'page_idx': 85,
#   'title': 'Data field',
#   'filename': 'cvn1716902605313.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/niAUJE1P6uv7lDnsvJNKxw',
#   'children': []},
#  {'page_idx': 86,
#   'title': 'Justification',
#   'filename': 'afd1716902895999.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/zrwhEF3yBq0jZmagTPDxeA',
#   'children': []},
#  {'page_idx': 87,
#   'title': 'Date and time attribute notations',
#   'filename': 'vqi1614570858310.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/nFGYFHVOttLhMqqxBSzy3w',
#   'children': []},
#  {'page_idx': 88,
#   'title': 'Entity descriptions',
#   'filename': 'gfi1614570854466.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/oz21alzuUtCGJQZ4RHlzVQ',
#   'children': []},
#  {'page_idx': 89,
#   'title': 'Presence notations',
#   'filename': 'zvt1614570858404.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vzUdBdiYDnQUElgvv4LDiw',
#   'children': []},
#  {'page_idx': 90,
#   'title': 'Program and service category notations',
#   'filename': 'odm1716496883861.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HwXDxWkGF5QxMSQvOAUDKA',
#   'children': []},
#  {'page_idx': 91,
#   'title': 'Presence requirement notations',
#   'filename': 'rzh1730389250187.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/kvsVQDu3ZQhGehlt1HaHow',
#   'children': []},
#  {'page_idx': 92,
#   'title': 'Bit map information',
#   'filename': 'wpz1719919092296.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/D2MRSt~ptADb7zOpAHB1Lg',
#   'children': []},
#  {'page_idx': 93,
#   'title': 'Authorization Request/0100',
#   'filename': 'amj1623207166280.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/EoH1yhfsmyr4hta6XnFIag',
#   'children': []},
#  {'page_idx': 94,
#   'title': 'Authorization Request Response/0110',
#   'filename': 'kfe1623207166360.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/nVZtVl8cfZ9cq1D3mTjetw',
#   'children': []},
#  {'page_idx': 95,
#   'title': 'Authorization Advice/0120: acquirer-generated',
#   'filename': 'ufk1623207166440.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lpkNjxcH1bTdEZzkh21oDw',
#   'children': []},
#  {'page_idx': 96,
#   'title': 'Authorization Advice/0120: system-generated',
#   'filename': 'jab1623207182649.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4LiI72VIeMbI4j4iuw8nOQ',
#   'children': []},
#  {'page_idx': 97,
#   'title': 'Authorization Advice Response/0130: issuer-generated (responding to a system-generated 0120)',
#   'filename': 'lzx1623207182729.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bOAZvlMSSzGM1XiUBM4vtg',
#   'children': []},
#  {'page_idx': 98,
#   'title': 'Authorization Advice Response/0130: issuer-generated (responding to an acquirer-generated 0120)',
#   'filename': 'loa1623207182809.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/XsZv6GPaq53SKB02bnMz0A',
#   'children': []},
#  {'page_idx': 99,
#   'title': 'Authorization Advice Response/0130: system-generated (responding to an acquirer-generated 0120)',
#   'filename': 'tyv1623207182888.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/BAHJGbsMAFgUQPeBHKCf8w',
#   'children': []},
#  {'page_idx': 100,
#   'title': 'Authorization Response Acknowledgment/0180',
#   'filename': 'oaw1623207183048.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/hO9sOa4E4QZd1SCIICaysg',
#   'children': []},
#  {'page_idx': 101,
#   'title': 'Authorization Response Negative Acknowledgment/0190',
#   'filename': 'nkc1623207183128.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/obnyRRYKFPsWrzM4ZtP7NA',
#   'children': []},
#  {'page_idx': 102,
#   'title': 'Issuer File Update Request/0302',
#   'filename': 'ffr1623207183217.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Xo4hGZPM8Kb9NCFdKsJ2XA',
#   'children': []},
#  {'page_idx': 103,
#   'title': 'Issuer File Update Request Response/0312',
#   'filename': 'pkd1623207183296.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/wzAulcFG7tbnGk4nJMVFJg',
#   'children': []},
#  {'page_idx': 104,
#   'title': 'Reversal Request/0400',
#   'filename': 'nuv1623207166520.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/we1RyXfIra5gztOTyrCA1A',
#   'children': []},
#  {'page_idx': 105,
#   'title': 'Reversal Request Response/0410',
#   'filename': 'amv1623207166616.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Saubp_PYBLRq2a6JJXxTdQ',
#   'children': []},
#  {'page_idx': 106,
#   'title': 'Reversal Advice/0420',
#   'filename': 'zrp1623207183377.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lZbDmGI0q8NRyzcqW2OyiA',
#   'children': []},
#  {'page_idx': 107,
#   'title': 'Reversal Advice Response/0430',
#   'filename': 'xzr1623207183537.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/UTx0Ssr57oSJ5ZuBh1knQA',
#   'children': []},
#  {'page_idx': 108,
#   'title': 'Administrative Request/0600',
#   'filename': 'mnx1623207183617.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HLEPXn152e~HcAF0jjyICA',
#   'children': []},
#  {'page_idx': 109,
#   'title': 'Administrative Request Response/0610',
#   'filename': 'hxk1623207183696.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/p2G0prSxsRLCBZwiplye4w',
#   'children': []},
#  {'page_idx': 110,
#   'title': 'Administrative Advice/0620: member-generated',
#   'filename': 'lsn1623207183873.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/VYtI_PPWoIsZ6mVPN_~84g',
#   'children': []},
#  {'page_idx': 111,
#   'title': 'Administrative Advice/0620: system-generated',
#   'filename': 'laq1623207183777.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/E7lB6w3WAv3H3TW11A0gfQ',
#   'children': []},
#  {'page_idx': 112,
#   'title': 'Administrative Advice Response/0630',
#   'filename': 'duu1623207183953.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/1MA~fecAle7gNg937DJfJw',
#   'children': []},
#  {'page_idx': 113,
#   'title': 'Network Management Request/0800: sign-on/sign-off',
#   'filename': 'tgk1623207184033.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Apea187FjEGK~kKXpCtwsg',
#   'children': []},
#  {'page_idx': 114,
#   'title': 'Network Management Request/0800: network-connection status, member-generated',
#   'filename': 'nma1623207184113.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/~w5wMxPFdeWs3owrSRp1gQ',
#   'children': []},
#  {'page_idx': 115,
#   'title': 'Network Management Request/0800: network-connection status, system-generated',
#   'filename': 'rod1623207184187.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/y4LZPWVTDi3vuK4Ssjh8Ug',
#   'children': []},
#  {'page_idx': 116,
#   'title': 'Network Management Request/0800: host-session activation/deactivation',
#   'filename': 'wzl1623207184268.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/oNwU_L75O5EZ4f~RsQsHmg',
#   'children': []},
#  {'page_idx': 117,
#   'title': 'Network Management Request/0800: PEK exchange',
#   'filename': 'zqp1623207184347.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/A1tcO8N_~Ct7MzRTaLTYbA',
#   'children': []},
#  {'page_idx': 118,
#   'title': 'Network Management Request/0800: PEK exchange on demand',
#   'filename': 'xtw1623207184427.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Oj_YgVlAyp07kEWnj5iF~Q',
#   'children': []},
#  {'page_idx': 119,
#   'title': 'Network Management Request Response/0810: sign-on/sign-off',
#   'filename': 'wws1728329006636.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/K~exzx6GcK_W5cTRF9q5gw',
#   'children': []},
#  {'page_idx': 120,
#   'title': 'Network Management Request Response/0810: network-connection status, member-generated',
#   'filename': 'zaq1623207184586.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/7jE9yOAGxb0pQVP2gHVocA',
#   'children': []},
#  {'page_idx': 121,
#   'title': 'Network Management Request Response/0810: network-connection status, system-generated',
#   'filename': 'vfy1623207184673.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vrvbOXYl5nK~8pzZmwuD8g',
#   'children': []},
#  {'page_idx': 122,
#   'title': 'Network Management Request Response/0810: host-session activation/deactivation',
#   'filename': 'hgb1623207184753.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/xDlveSIBWK188yRdyGUk9g',
#   'children': []},
#  {'page_idx': 123,
#   'title': 'Network Management Request Response/0810: PEK exchange',
#   'filename': 'kyc1623207184834.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/UHQ1nTor__OdfB5FTjGj9g',
#   'children': []},
#  {'page_idx': 124,
#   'title': 'Network Management Request Response/0810: PEK exchange on demand',
#   'filename': 'lcx1623207184914.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ImGM_MHiJX8x1VVn0kq8xA',
#   'children': []},
#  {'page_idx': 125,
#   'title': 'Network Management Advice/0820: PEK exchange',
#   'filename': 'fwo1623207184993.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/I25EdGlOZOoXVhhqlz956w',
#   'children': []},
#  {'page_idx': 92,
#   'title': 'Message types',
#   'filename': 'pvn1713899741647.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JJkwaxZwh1d6dYwns241zg',
#   'children': [92,
#    93,
#    94,
#    95,
#    96,
#    97,
#    98,
#    99,
#    100,
#    101,
#    102,
#    103,
#    104,
#    105,
#    106,
#    107,
#    108,
#    109,
#    110,
#    111,
#    112,
#    113,
#    114,
#    115,
#    116,
#    117,
#    118,
#    119,
#    120,
#    121,
#    122,
#    123,
#    124,
#    125]},
#  {'page_idx': 83,
#   'title': 'General message layout information',
#   'filename': 'mvs1717694027033.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/WqK4qCfSIicVbJMpOAiNEQ',
#   'children': [83, 84, 85, 86, 87, 88, 89, 90, 91, 92]},
#  {'page_idx': 128,
#   'title': 'Subelement layout',
#   'filename': 'ngy1714485399433.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/x9zii3D3dUYBTR_ScQAwIQ',
#   'children': []},
#  {'page_idx': 129,
#   'title': 'Subfield layout',
#   'filename': 'aps1714485966743.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/krOSOn0LYJxfYWg68OUcGQ',
#   'children': []},
#  {'page_idx': 130,
#   'title': 'Position layout',
#   'filename': 'igh1714486267542.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/8ouaKN4Qwp3lW6dOJdhutA',
#   'children': []},
#  {'page_idx': 131,
#   'title': 'Primary Bit Map',
#   'filename': 'aza1623207185737.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/39VZVZx2~WH8feQ1bJF59A',
#   'children': []},
#  {'page_idx': 132,
#   'title': 'DE 1 (Bit Map, Secondary)',
#   'filename': 'jlr1623207185817.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/2YgAjrKWUD0Cr1Bnt4gRNQ',
#   'children': []},
#  {'page_idx': 133,
#   'title': 'About Primary Account Number',
#   'filename': 'bop1623207185976.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/~iVW~aX3aKz~3MxNj2yDNg',
#   'children': []},
#  {'page_idx': 133,
#   'title': 'DE 2 (Primary Account Number [PAN])',
#   'filename': 'uqm1623207185896.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/1Xq4M~5DR97eS8DoboBVSw',
#   'children': [133]},
#  {'page_idx': 135,
#   'title': 'Subfield 1 (Cardholder Transaction Type Code)',
#   'filename': 'kaz1623207166943.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/N2btuCfwrNoejt_0e2dpwg',
#   'children': []},
#  {'page_idx': 136,
#   'title': 'Subfield 2 (Cardholder From Account Type Code)',
#   'filename': 'gdm1623207186151.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/uwyCAELp5nVOUTfoQu~QVQ',
#   'children': []},
#  {'page_idx': 137,
#   'title': 'Subfield 3 (Cardholder To Account Type Code)',
#   'filename': 'ebd1623207186232.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/pqw5u0ShDr8gMhHI_OFZAQ',
#   'children': []},
#  {'page_idx': 135,
#   'title': 'DE 3 (Processing Code)',
#   'filename': 'yyq1623207186055.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4QWMctN8aNAVkPguS5fyvQ',
#   'children': [135, 136, 137]},
#  {'page_idx': 139,
#   'title': 'DE 4 (Amount, Transaction)',
#   'filename': 'ncs1623207186312.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/2p3gF2yDJMMBAmmJuABxyg',
#   'children': []},
#  {'page_idx': 140,
#   'title': 'DE 5 (Amount, Settlement)',
#   'filename': 'pej1623207186407.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4YjpGmZFTOiRsetGfMy2dQ',
#   'children': []},
#  {'page_idx': 141,
#   'title': 'DE 6 (Amount, Cardholder Billing)',
#   'filename': 'gwk1623207167037.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/sIOafxwuxs3ihW8ef82XhA',
#   'children': []},
#  {'page_idx': 142,
#   'title': 'Subfield 1 (Date)',
#   'filename': 'pkj1623207186567.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ir3TsCd6OLzrKRnil~jB7g',
#   'children': []},
#  {'page_idx': 143,
#   'title': 'Subfield 2 (Time)',
#   'filename': 'xtn1623207186631.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Fd2BeQlvnZfzeGX57gg7Ew',
#   'children': []},
#  {'page_idx': 142,
#   'title': 'DE 7 (Transmission Date and Time)',
#   'filename': 'qgy1623207186487.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/WUv4DIxOP~Vfgz7ymexd0Q',
#   'children': [142, 143]},
#  {'page_idx': 145,
#   'title': 'DE 8 (Amount, Cardholder Billing Fee)',
#   'filename': 'zvw1623207186726.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/UUKwaL5q02OFvoWgyP2Zrw',
#   'children': []},
#  {'page_idx': 146,
#   'title': 'Subfield 1 (Decimal Indicator)',
#   'filename': 'yjy1623207186799.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vizMiV2BGlLAEKg989KSLw',
#   'children': []},
#  {'page_idx': 147,
#   'title': 'Subfield 2 (Conversion Rate)',
#   'filename': 'qzz1623207186878.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Bw0apmHo0MqDlCibWynkhg',
#   'children': []},
#  {'page_idx': 146,
#   'title': 'DE 9 (Conversion Rate, Settlement)',
#   'filename': 'gua1623207166024.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/eSXpbGpUJj03rTkU0HduLA',
#   'children': [146, 147]},
#  {'page_idx': 149,
#   'title': 'Subfield 1 (Decimal Indicator)',
#   'filename': 'chp1623207186968.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/WVtDY~xzFQkK3VGkxRgMzA',
#   'children': []},
#  {'page_idx': 150,
#   'title': 'Subfield 2 (Cardholder Billing Conversion Rate)',
#   'filename': 'miw1623207187037.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/YEk0baisQ9vEDdeovRsy1g',
#   'children': []},
#  {'page_idx': 149,
#   'title': 'DE 10 (Conversion Rate, Cardholder Billing)',
#   'filename': 'ylo1623207166104.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/EZS97wp5kyp9dl7S2mAXUQ',
#   'children': [149, 150]},
#  {'page_idx': 152,
#   'title': 'DE 11 (System Trace Audit Number [STAN])',
#   'filename': 'akp1623207187117.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/jIVIEXebvVfadd2LqwYuIQ',
#   'children': []},
#  {'page_idx': 153,
#   'title': 'DE 12 (Time, Local Transaction)',
#   'filename': 'wxi1623207187209.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Rkq_WYix0vs5kufkDM5ZpA',
#   'children': []},
#  {'page_idx': 154,
#   'title': 'DE 13 (Date, Local Transaction)',
#   'filename': 'rhh1623207187289.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Vv7FgTDWEm4_KNyRUB~RuA',
#   'children': []},
#  {'page_idx': 155,
#   'title': 'DE 14 (Date, Expiration)',
#   'filename': 'xle1623207187369.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bgoTRPagcWKxw6hDZ7YtYg',
#   'children': []},
#  {'page_idx': 156,
#   'title': 'DE 15 (Date, Settlement)',
#   'filename': 'mfz1623207187448.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ELqD~53PKqZp_bae~Gm74g',
#   'children': []},
#  {'page_idx': 157,
#   'title': 'DE 16 (Date, Conversion)',
#   'filename': 'qdw1623207187528.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/S~3oERlHMEflPhK9vfb0jw',
#   'children': []},
#  {'page_idx': 158,
#   'title': 'DE 17 (Date, Capture)',
#   'filename': 'nxe1623207187608.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/WTUxGEGYOyzopuYrn5QhoA',
#   'children': []},
#  {'page_idx': 159,
#   'title': 'DE 18 (Merchant Type)',
#   'filename': 'urf1623207187690.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/g_v2tJ2s5uQ_ELfFioho7A',
#   'children': []},
#  {'page_idx': 160,
#   'title': 'DE 19 (Acquiring Institution Country Code)',
#   'filename': 'uwg1623207187770.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/VXvnx3GTq3sH0lbqWV3PTA',
#   'children': []},
#  {'page_idx': 161,
#   'title': 'DE 20 (Primary Account Number [PAN] Country Code)',
#   'filename': 'iwx1623207187849.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/hj1kmuXGpiMhNsZFakBkvA',
#   'children': []},
#  {'page_idx': 162,
#   'title': 'DE 21 (Forwarding Institution Country Code)',
#   'filename': 'tdp1623207187929.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4wvkCTqKCR0IONxpJI16pg',
#   'children': []},
#  {'page_idx': 163,
#   'title': 'Subfield 1 (POS Terminal PAN Entry Mode)',
#   'filename': 'utj1623207188169.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/PPql75jsD1k2fBTJnfdSUg',
#   'children': []},
#  {'page_idx': 164,
#   'title': 'Subfield 2 (POS Terminal PIN Entry Mode)',
#   'filename': 'ycp1623207188248.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ioIjBGyAvBDT3RYpgDIsxw',
#   'children': []},
#  {'page_idx': 165,
#   'title': 'Electronic commerce transactions',
#   'filename': 'afa1623207188328.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/I7iuBIxWljK_7HJ8fcONXQ',
#   'children': []},
#  {'page_idx': 166,
#   'title': 'Mastercard Consumer Presented QR Transactions',
#   'filename': 'oed1623207188408.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/CJ1UQUFJNtBvZ~Lb_gEAcA',
#   'children': []},
#  {'page_idx': 167,
#   'title': 'Chip transactions',
#   'filename': 'mwg1623207188487.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/lz0q~zcpx8WMxmw9VuKy9w',
#   'children': []},
#  {'page_idx': 168,
#   'title': 'Contactless Magnetic Stripe Transactions',
#   'filename': 'gjz1623207188631.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/TCxM00ymdA4It1TFjA6jHg',
#   'children': []},
#  {'page_idx': 169,
#   'title': 'Credential on File Transactions',
#   'filename': 'kpz1623207188741.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ar~s8UB8ieGBzeGwdXSf0g',
#   'children': []},
#  {'page_idx': 165,
#   'title': 'Dual Message Authorization System edits',
#   'filename': 'fee1623207188074.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Lph67yu6f12U9b8WcrUksg',
#   'children': [165, 166, 167, 168, 169]},
#  {'page_idx': 163,
#   'title': 'DE 22 (Point-of-Service [POS] Entry Mode)',
#   'filename': 'ydb1623207188010.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/qQqQ6Y1oqiTZT9~LxGaqKA',
#   'children': [163, 164, 165]},
#  {'page_idx': 172,
#   'title': 'DE 23 (Card Sequence Number)',
#   'filename': 'bgx1623207188816.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/1LWObQwqAveoAuIZEMHJHA',
#   'children': []},
#  {'page_idx': 173,
#   'title': 'DE 24 (Network International ID)',
#   'filename': 'njf1623207188895.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/QCdErNy4riiAoW~8wpnqPw',
#   'children': []},
#  {'page_idx': 174,
#   'title': 'DE 25 (Point-of-Service [POS] Condition Code)',
#   'filename': 'lqd1623207188976.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/FSWWtsuos1dIJR6GK4Y2Sw',
#   'children': []},
#  {'page_idx': 175,
#   'title': 'DE 26 (Point-of-Service (POS) Personal ID Number [PIN] Capture Code)',
#   'filename': 'ckv1623207189055.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/dE~9itKFR~rPEOumVhYjUA',
#   'children': []},
#  {'page_idx': 176,
#   'title': 'DE 27 (Authorization ID Response Length)',
#   'filename': 'loy1623207189135.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/B31JO_jBHFryUuBasWf19Q',
#   'children': []},
#  {'page_idx': 177,
#   'title': 'Subfield 1 (Debit/Credit Indicator)',
#   'filename': 'dhz1623207189296.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/1EaR1BzDEhpfrOi9kiRekQ',
#   'children': []},
#  {'page_idx': 178,
#   'title': 'Subfield 2 (Amount)',
#   'filename': 'gyp1623207189376.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/7xlChLIwGcT5WRrPQEgy8Q',
#   'children': []},
#  {'page_idx': 177,
#   'title': 'DE 28 (Amount, Transaction Fee)',
#   'filename': 'muy1623207189217.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/_jWDLTgkn_TL~eleWXu1hQ',
#   'children': [177, 178]},
#  {'page_idx': 180,
#   'title': 'DE 29 (Amount, Settlement Fee)',
#   'filename': 'gsv1623207189457.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/QLQDjn0PEEkn1iFeY3~hOA',
#   'children': []},
#  {'page_idx': 181,
#   'title': 'DE 30 (Amount, Transaction Processing Fee)',
#   'filename': 'twx1623207189696.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/8S3pOy6zgFot87R4NvSmEA',
#   'children': []},
#  {'page_idx': 182,
#   'title': 'DE 31 (Amount, Settlement Processing Fee)',
#   'filename': 'hnh1623207189937.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/utYUfntMsEQiXA2dRZG8GA',
#   'children': []},
#  {'page_idx': 183,
#   'title': 'DE 32 (Acquiring Institution ID Code)',
#   'filename': 'aag1623207190168.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/RiTHsNGtJJ9LdaULs4oD8A',
#   'children': []},
#  {'page_idx': 184,
#   'title': 'DE 33 (Forwarding Institution ID Code)',
#   'filename': 'jyd1623207190248.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/JbQ8qTFS8yByEVSP7DtERw',
#   'children': []},
#  {'page_idx': 185,
#   'title': 'DE 34 (Primary Account Number [PAN], Extended)',
#   'filename': 'dxj1623207190328.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/qwNORrdwc_4ClEgaJ8yCCw',
#   'children': []},
#  {'page_idx': 186,
#   'title': 'DE 35 (Track 2 Data)',
#   'filename': 'phb1623207167117.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/nHqzLkLhdFV1J~OL3txWEA',
#   'children': []},
#  {'page_idx': 187,
#   'title': 'DE 36 (Track 3 Data)',
#   'filename': 'blv1623207190408.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/uSz~yCtheIhBKvbsAjSJdw',
#   'children': []},
#  {'page_idx': 188,
#   'title': 'Subfield 1 (Transaction Date and Initiator Discretionary Data)',
#   'filename': 'xdc1623207190577.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/SFvsN4vX4AT~EWmuutetCw',
#   'children': []},
#  {'page_idx': 189,
#   'title': 'Subfield 2 (Terminal Transaction Number)',
#   'filename': 'bvi1623207190659.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/~i6_Er4ojwHI_VLZTo09jw',
#   'children': []},
#  {'page_idx': 188,
#   'title': 'DE 37 (Retrieval Reference Number)',
#   'filename': 'uce1623207190487.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/kO0KrOTZuZcfxC88D9QWUw',
#   'children': [188, 189]},
#  {'page_idx': 191,
#   'title': 'DE 38 (Authorization ID Response)',
#   'filename': 'lrs1623207167201.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/0Gpnk6JAc01yV2s5i91KpA',
#   'children': []},
#  {'page_idx': 192,
#   'title': 'Best practices for DE 39 values in Authorization Request Response/0110 response codes',
#   'filename': 'pac1753219069514.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ljplz7Sso9ghz4U9_fm70Q',
#   'children': []},
#  {'page_idx': 192,
#   'title': 'Authorization Request Response/0110 response codes',
#   'filename': 'aaj1623207167360.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/uLZENs_D_D3Ig9f4yqTwNg',
#   'children': [192]},
#  {'page_idx': 194,
#   'title': 'Authorization Advice/0120 response codes',
#   'filename': 'mlo1623207190736.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Zj8nT3O_G4JcCxyDoNyVJA',
#   'children': []},
#  {'page_idx': 195,
#   'title': 'Authorization Advice Response/0130 response codes',
#   'filename': 'gym1623207190817.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/E1n278kYMMzPuw9H6gC6Fg',
#   'children': []},
#  {'page_idx': 196,
#   'title': 'Authorization Response Acknowledgment/0180 response codes',
#   'filename': 'ktw1623207190896.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/2cw2K5adury_EaAx_CdFoA',
#   'children': []},
#  {'page_idx': 197,
#   'title': 'Authorization Response Negative Acknowledgment/0190 response codes',
#   'filename': 'hnf1623207190978.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/NC1aRJXGp4kOyDC_BfUBWA',
#   'children': []},
#  {'page_idx': 198,
#   'title': 'Issuer File Update Request Response/0312 response codes',
#   'filename': 'vvc1623207191057.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/WvnLl9SKDeuH8otfT3MBRg',
#   'children': []},
#  {'page_idx': 199,
#   'title': 'Reversal Request/0400 response codes',
#   'filename': 'gvj1623207191138.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/rPXZr~ILp96lF6MFpuyVWw',
#   'children': []},
#  {'page_idx': 200,
#   'title': 'Reversal Request Response/0410 response codes',
#   'filename': 'dsj1623207191233.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/aY_7zErnEmR~L~5uwLjdiA',
#   'children': []},
#  {'page_idx': 201,
#   'title': 'Reversal Advice/0420 response codes',
#   'filename': 'kyj1623207191329.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/NzuRZ6XDSaVK9FQl~QIgdQ',
#   'children': []},
#  {'page_idx': 202,
#   'title': 'Reversal Advice Response/0430 Message and Administrative Advice Response/0630 response codes',
#   'filename': 'bwy1623207191409.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/pau94kBEz276zm2MOK49QQ',
#   'children': []},
#  {'page_idx': 203,
#   'title': 'Administrative Request Response/0610 response codes',
#   'filename': 'fuh1623207191488.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4Adw7SN2DjcgkHsll5hxcQ',
# ...
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/MKmJj1xi0ycLTz8jLmY4Rw',
#   'children': [926, 927, 928, 929, 930]},
#  {'page_idx': 932,
#   'title': 'Subfield 01 (Primary Cardholder Identifier)',
#   'filename': 'fie1623207234263.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/0E5M6Xbcy2ofoTadJOOLJA',
#   'children': []},
#  {'page_idx': 933,
#   'title': 'Subfield 02 (Secondary Cardholder Identifier)',
#   'filename': 'iwk1623207234344.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4Sf_muWyOms8BL~rtRrK1g',
#   'children': []},
#  {'page_idx': 932,
#   'title': 'Subelement 037 (Additional Cardholder Information)',
#   'filename': 'xbx1623207234184.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/4JjergHNhLRhcRQ6VbbBPA',
#   'children': [932, 933]},
#  {'page_idx': 932,
#   'title': 'Netherlands: IBAN (Account Inquiry)',
#   'filename': 'mww1623207234104.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/ylaaaEc5pPKPtWnverCBlw',
#   'children': [932]},
#  {'page_idx': 936,
#   'title': 'Subelement 042 (Acceptor Tax ID)',
#   'filename': 'ajc1624289578876.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/~qiNr2XO_BfaEzdx4IqsfA',
#   'children': []},
#  {'page_idx': 936,
#   'title': 'Paraguay: Payment Transactions',
#   'filename': 'isl1624289413826.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/iWdirAoBDcGaPOoSuavi8w',
#   'children': [936]},
#  {'page_idx': 938,
#   'title': 'Subelement 001 (Installment Payment Data)',
#   'filename': 'gqt1623207234504.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/aJytX0Z7TiNnLVT0I8ecwA',
#   'children': []},
#  {'page_idx': 939,
#   'title': 'Subelement 002 (Installment Payment Response Data)',
#   'filename': 'kqs1623207234601.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/TOWMkhkHyJLhKJxdR_m9Zw',
#   'children': []},
#  {'page_idx': 940,
#   'title': 'Subelement 016 (Additional Installment Payment Response Data)',
#   'filename': 'xrd1623207234680.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bnZmmyqc9Uf9ZUwFn86eWQ',
#   'children': []},
#  {'page_idx': 938,
#   'title': 'Parcelas: Payment Transactions',
#   'filename': 'wfz1623207234424.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vhU7dsPu2pM0RaLqtIlxbA',
#   'children': [938, 939, 940]},
#  {'page_idx': 942,
#   'title': 'Subelement 007 (Installment Payment Data)',
#   'filename': 'jhz1623207234840.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/3UcgTMUnvutNQocN531XZQ',
#   'children': []},
#  {'page_idx': 943,
#   'title': 'Subelement 008 (Installment Payment Response Data)',
#   'filename': 'vkc1623207234920.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ho9nh0r4nBoGEB0jCU2rOA',
#   'children': []},
#  {'page_idx': 942,
#   'title': 'Percta: Payment Transactions',
#   'filename': 'jif1623207234760.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/fmlNtMXm8G_Z7ko2TEi5XQ',
#   'children': [942, 943]},
#  {'page_idx': 945,
#   'title': 'Subelement 041 (Poland VAT Data)',
#   'filename': 'rfh1644349921301.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/nKQd45FtU6R~E7aj0vVqPA',
#   'children': []},
#  {'page_idx': 945,
#   'title': 'Poland: Value-Added Tax specifications',
#   'filename': 'wnk1728317885585.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/XztDse55wodpUiqZNJhe7Q',
#   'children': [945]},
#  {'page_idx': 947,
#   'title': 'Subfield 1 (ATM Service Fee)',
#   'filename': 'wnx1623207235167.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HQflYtRsOAOlH_0J3L2tJg',
#   'children': []},
#  {'page_idx': 948,
#   'title': 'Subfield 2 (ATM Disloyalty Fee)',
#   'filename': 'axi1623207235235.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/VAO9oIviEnkOvnqoYv1CBg',
#   'children': []},
#  {'page_idx': 949,
#   'title': 'Subfield 3 (Credit Card Fee)',
#   'filename': 'oyg1623207235316.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/hWQJk7QxaZJQE6aLP0tc_Q',
#   'children': []},
#  {'page_idx': 947,
#   'title': 'Subelement 017 (ATM Domestic Fee)',
#   'filename': 'zle1623207235080.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/INonoGT1tuc4d83Kw7c3FA',
#   'children': [947, 948, 949]},
#  {'page_idx': 947,
#   'title': 'Spain: Domestic ATM Transactions',
#   'filename': 'tqm1623207235001.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/qfbw7q5wISh2g7stnBq8Yw',
#   'children': [947]},
#  {'page_idx': 952,
#   'title': 'Subelement 038 (Taiwan National Data)',
#   'filename': 'cdq1623207170818.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/BQ58TT7UsKr8oD5_l5FHNA',
#   'children': []},
#  {'page_idx': 952,
#   'title': 'Taiwan: National Data',
#   'filename': 'oqz1623207170738.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/RbgXNaZa~_dzlExYYnQCwA',
#   'children': [952]},
#  {'page_idx': 954,
#   'title': 'Subfield 1 (Recipient Last Name)',
#   'filename': 'jce1623207235595.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/uAPU2vK_9ccLPZz30jpgrA',
#   'children': []},
#  {'page_idx': 955,
#   'title': 'Subfield 2 (Recipient Postal Code)',
#   'filename': 'aek1623207235674.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/dqo3A9Hpd1J5fGiHax1Qlw',
#   'children': []},
#  {'page_idx': 956,
#   'title': 'Subfield 3 (Recipient Date of Birth)',
#   'filename': 'zsn1623207235747.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/3PCKgF8hoZ8c3uZk~CTk~A',
#   'children': []},
#  {'page_idx': 957,
#   'title': 'Subfield 4 (Recipient Account Number)',
#   'filename': 'oco1623207235843.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/SHxqZrg9pPbAPeWjJyuinQ',
#   'children': []},
#  {'page_idx': 954,
#   'title': 'Subelement 033 (UK Recipient Details)',
#   'filename': 'nph1623207235510.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/CO43schohkf6NA6ZX5JetQ',
#   'children': [954, 955, 956, 957]},
#  {'page_idx': 954,
#   'title': 'United Kingdom: Debt Repayment Transactions',
#   'filename': 'ixu1623207235427.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/iNCiS_WYCQCuHGwCpDKHtw',
#   'children': [954]},
#  {'page_idx': 836,
#   'title': 'DE 112 (Additional Data [National Use])',
#   'filename': 'pfi1623207228376.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/On~wotOkedqS0eX1K3HAYA',
#   'children': [836,
#    837,
#    838,
#    839,
#    843,
#    846,
#    847,
#    853,
#    860,
#    862,
#    864,
#    867,
#    870,
#    873,
#    886,
#    890,
#    895,
#    898,
#    900,
#    914,
#    926,
#    932,
#    936,
#    938,
#    942,
#    945,
#    947,
#    952,
#    954]},
#  {'page_idx': 961,
#   'title': 'DE 113 (Reserved for National Use)',
#   'filename': 'xgp1623207235923.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/YEZ3Tqp~NZBk~p64R9bQtQ',
#   'children': []},
#  {'page_idx': 962,
#   'title': 'DE 114 (Reserved for National Use)',
#   'filename': 'dcr1623207236175.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/D5AuIC66sKVohHkA7t72vA',
#   'children': []},
#  {'page_idx': 963,
#   'title': 'DE 115 (Reserved for National Use)',
#   'filename': 'ivm1623207236674.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/YSlm4geQz5_HcpmMll75qw',
#   'children': []},
#  {'page_idx': 964,
#   'title': 'DE 116 (Reserved For National Use)',
#   'filename': 'zqh1623207237185.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/s9GQKxNT441RTyo4exHHxg',
#   'children': []},
#  {'page_idx': 965,
#   'title': 'DE 117 (Reserved for National Use)',
#   'filename': 'lxb1623207237505.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/z8tZiE_OFRYtKaD7e1zChQ',
#   'children': []},
#  {'page_idx': 966,
#   'title': 'DE 118 (Reserved for National Use)',
#   'filename': 'yaf1623207237841.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/RxgnlC6FeOYu0kZi1dA6Aw',
#   'children': []},
#  {'page_idx': 967,
#   'title': 'DE 119 encoding scheme',
#   'filename': 'ojk1708015964962.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/qFbJlpEnfY2GzsNxC_WTbw',
#   'children': []},
#  {'page_idx': 968,
#   'title': 'DE 119 subelement encoding scheme',
#   'filename': 'nyr1707926670505.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Yl4gMIbHbScAD0P2ytsMLA',
#   'children': []},
#  {'page_idx': 967,
#   'title': 'DE 119 (Additional Data: Private Use 2)',
#   'filename': 'nht1707772080128.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/MlpOftYKK8UOKFm0roviSQ',
#   'children': [967, 968]},
#  {'page_idx': 970,
#   'title': 'Subfield 01 (AVS Service Indicator 1)',
#   'filename': 'cit1623207238409.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/LTblnmLSRpBGLOCiTBva2A',
#   'children': []},
#  {'page_idx': 971,
#   'title': 'Subfield 02 (AVS Service Indicator 2)',
#   'filename': 'gmm1623207238488.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/onBKp6wDPZ5lWyNnzSJ7Kw',
#   'children': []},
#  {'page_idx': 972,
#   'title': 'Subfield 03 (AVS Service Indicator 3)',
#   'filename': 'ytx1623207238585.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/dwenvx2om2qIljOYBFA3ZQ',
#   'children': []},
#  {'page_idx': 973,
#   'title': 'Subfield 04 (AVS Service Indicator 4)',
#   'filename': 'emn1623207238664.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/DED4yWfEUXPtPN_SwRffKQ',
#   'children': []},
#  {'page_idx': 974,
#   'title': 'MCC 102: Stand-In Account File',
#   'filename': 'qax1623207238760.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HluyUigd4Iqzfv~G4M2QVg',
#   'children': []},
#  {'page_idx': 975,
#   'title': 'MCC 103: Electronic Warning Bulletin File',
#   'filename': 'cfu1623207238840.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/Ex1VBZcv8GSpMfirvMbkow',
#   'children': []},
#  {'page_idx': 976,
#   'title': 'MCC 104: Local Stoplist File',
#   'filename': 'noe1623207238921.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/y2QzB~6vtVq2qJZViUwH2g',
#   'children': []},
#  {'page_idx': 977,
#   'title': 'DE 120 (When Blocking Recurring Payments)',
#   'filename': 'utr1623207239085.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/RLLqsIwfIXrSgxN9vtrU6A',
#   'children': []},
#  {'page_idx': 977,
#   'title': 'MCC 105: Payment Cancellation File',
#   'filename': 'qxe1623207239004.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/o2Qmp~_xa~6KPu4fqEDNjg',
#   'children': [977]},
#  {'page_idx': 979,
#   'title': 'MCC 106: PAN Mapping File',
#   'filename': 'sll1623207170897.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/9rgNTyrxcVjP2R8BfD3hoA',
#   'children': []},
#  {'page_idx': 980,
#   'title': 'MCC 109: Application Transaction Counter File',
#   'filename': 'hma1623207239171.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/bPo54i~CwOgdbto8m~6rfw',
#   'children': []},
#  {'page_idx': 981,
#   'title': 'MCC 111: PAN-PAR (Payment Account Reference) Mapping File',
#   'filename': 'zrd1623207239251.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/zRVE9H0NwOnT4Wwq2KcyEA',
#   'children': []},
#  {'page_idx': 982,
#   'title': 'MCC 102: Error Codes',
#   'filename': 'mtu1623207239332.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/7JxmA_Qcvl79R71Xrc6tFA',
#   'children': []},
#  {'page_idx': 983,
#   'title': 'MCC 103: Error Codes',
#   'filename': 'ycx1623207239412.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/vttUPP4sAZuz2ipvKGJHCQ',
#   'children': []},
#  {'page_idx': 984,
#   'title': 'MCC 104: Error Codes',
#   'filename': 'rsa1623207239491.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/M0OwjEh4ofpbxQh6LneiLA',
#   'children': []},
#  {'page_idx': 985,
#   'title': 'MCC 105: Error Codes',
#   'filename': 'pfa1623207239587.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HNCxxjGtOI22BgVg_P8vcQ',
#   'children': []},
#  {'page_idx': 986,
#   'title': 'MCC 106: Error Codes',
#   'filename': 'fdb1623207170978.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/st9PU9t2qaaMmwNGEpggVw',
#   'children': []},
#  {'page_idx': 987,
#   'title': 'MCC 109: Error Codes',
#   'filename': 'qei1623207239668.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/mrRy9iknkEd9GJEHVKmejQ',
#   'children': []},
#  {'page_idx': 988,
#   'title': 'MCC 111: Error Codes',
#   'filename': 'cpt1623207239749.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/HXMkIfUr1A_Pu3l6lUP5nA',
#   'children': []},
#  {'page_idx': 982,
#   'title': 'DE 120 (Error Codes)',
#   'filename': 'cps1623207171139.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/xokK_FDnysvH7T6OHQK7Iw',
#   'children': [982, 983, 984, 985, 986, 987, 988]},
#  {'page_idx': 974,
#   'title': 'Online file maintenance',
#   'filename': 'wnv1623207171058.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/f~WOuESqHbCahfojfsrpYg',
#   'children': [974, 975, 976, 977, 979, 980, 981, 982]},
#  {'page_idx': 970,
#   'title': 'DE 120 (Record Data)',
#   'filename': 'erc1623207238329.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/cgjJMgkXZPxDTJPxS00zCA',
#   'children': [970, 971, 972, 973, 974]},
#  {'page_idx': 992,
#   'title': 'DE 121 (Authorizing Agent ID Code)',
#   'filename': 'mdh1623207239832.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/sjfsCGhXjJ9wYtOTIAKNnQ',
#   'children': []},
#  {'page_idx': 993,
#   'title': 'Subfield 001 (Acceptor Street Address)',
#   'filename': 'eor1642604984278.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/gmJTNFr35zFADmS3ssRR0Q',
#   'children': []},
#  {'page_idx': 994,
#   'title': 'Subfield 002 (Acceptor Country Subdivision Code)',
#   'filename': 'qtf1642605026927.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/L1OV4Q4IGu4ennCKaa5wfg',
#   'children': []},
#  {'page_idx': 995,
#   'title': 'Subfield 003 (Acceptor URL address)',
#   'filename': 'lkw1642605049823.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/olu92KuiHh1w4wlzo9wMpQ',
#   'children': []},
#  {'page_idx': 996,
#   'title': 'Subfield 004 (Acceptor Customer Service Phone Number)',
#   'filename': 'tuw1642605073280.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/kLvRuod1IB8~9G~K~T2K2g',
#   'children': []},
#  {'page_idx': 997,
#   'title': 'Subfield 005 (Acceptor Phone Number)',
#   'filename': 'wxz1642605100145.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/RIo_7DEPlhZGE0khe1LSyg',
#   'children': []},
#  {'page_idx': 998,
#   'title': 'Subfield 006 (Acceptor Additional Contact Information)',
#   'filename': 'obm1642605129988.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/TudN8_0205BhSvVvAPaRBg',
#   'children': []},
#  {'page_idx': 999,
#   'title': 'Subfield 007 (Acceptor Tax ID)',
#   'filename': 'eeh1642605148735.html',
#   'url': 'https://trc-techresource.mastercard.com/r/ezXh6dvgLV1nzevBm9aHDA/j7QAP_8OyW3SajNVuy7law',
#   'children': []},
#  ...]

# %% [markdown]
# ### HyperLinks
# #### Images

# %%
# dict of image hyperlinks 
# in the query text, just write filename.jpg 
# image will be attached to chunks at the query time 

url2img_map = {}
import json 
with open('DMAS_IMG_MAP.json') as f:
    img_map = json.load(f)

for idx, img_info in enumerate(img_map):
    id_ = img_info['id']
    # filename = img_info['filename']
    src_url = f'https://trc-techresource.mastercard.com/api/khub/maps/{DOC_ID}/resources/{id_}/content'
    view_url = f'https://trc-techresource.mastercard.com/viewer/attachment/{DOC_ID}/{id_}'
    url2img_map.update(
        {
            src_url: idx,
            view_url: idx  
        }
    )

# %% [markdown]
# #### Text

# %%
# map hyperlink to page_id, which is position itself

page_urls = {page_meta['url']:idx for idx, page_meta in enumerate(flattened_document_meta)}

# %%
import re
def get_urls(chunk_content:str):
    urls = re.findall(r'https://[^)\s]*', chunk_content)
    images_idx = set()
    page_links = set()

    # images
    for url in urls:
        if url in url2img_map:
            img_idx = url2img_map[url]
            chunk_content = chunk_content.replace(url, f'$image_{images_idx}$')
            images_idx.add(img_idx)
            
        if url in page_urls:
            page_idx = page_urls[url]
            page_links.add(page_idx)
            chunk_content = chunk_content.replace(url, f'$page_{page_idx}$')
    return chunk_content, list(page_links), list(images_idx)

# %% [markdown]
# ### Chunking

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter
CHUNK_SIZE = 4000
CHUNK_OVERLAP = 0.2*CHUNK_SIZE

def split_page_by_size(page_text:str):
    headings = []
    for line in page_text.splitlines():
        if line.startswith('#'):
            headings.append(line)
        else:
            break
    if len(page_text) > CHUNK_SIZE:
        recursive_splitter = RecursiveCharacterTextSplitter(
            chunk_size=CHUNK_SIZE ,   # keep small here for demo, usually 500–1000
            chunk_overlap=CHUNK_OVERLAP
        )
        final_chunks = []
        first_chunk = True
        for sub in recursive_splitter.split_text(page_text):
            if first_chunk:
                first_chunk = False 
            else:
                sub = '\n'.join(headings + [sub])
                
            final_chunks.append(
                sub
            )
    else:
        final_chunks = [page_text]
    return final_chunks

# %%
# chunking 
# split by headings if possible else do overlap chunking 
from langchain.text_splitter import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter
CHUNK_SIZE = 4000
CHUNK_OVERLAP = 0.2*CHUNK_SIZE

def split_page_by_headers(page_text:str):
    headers_to_split_on = [
        ("#", "#"),
        ("##", "##"),
        # ("###", "Header 3"),
    ]

    md_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on, strip_headers=False)
    md_chunks = md_splitter.split_text(page_text)

    # Step 2: Further split large sections with RecursiveCharacterTextSplitter
    recursive_splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE ,   # keep small here for demo, usually 500–1000
        chunk_overlap=CHUNK_OVERLAP
    )

    final_chunks = []
    for chunk in md_chunks:
        header_meta = (f'# {chunk.metadata.get('#')}' if chunk.metadata.get('#') else ''), (f'## {chunk.metadata.get('##')}' if chunk.metadata.get('##') else '') 
        title_str = '\n'.join([t for t in header_meta if t.strip()])

        if len(chunk.page_content) > CHUNK_SIZE:
            # re-split this big chunk
            sub_chunks = recursive_splitter.split_text(chunk.page_content)
            # each chunk should contain sub heading?
            first_chunk = True
            for sub in sub_chunks:
                if first_chunk:
                    first_chunk = False 
                else:
                    sub = '\n'.join([title_str, sub]) if title_str.strip() else sub
                final_chunks.append(
                    sub
                )
        else:
            final_chunks.append(
                chunk.page_content
            )

    return final_chunks

# %%
from markdownify import markdownify
import re 
import os 
os.system('del /f /q chunks\\*.md')

from tqdm import tqdm 
for page_meta in tqdm(flattened_document_meta, ncols=100):
    with open('content\\' + page_meta['filename'], mode='r', encoding='utf-8', errors='surrogatepass') as f:
        file_content = f.read()
        markdown_content = markdownify(file_content, heading_style='ATX')
        # remove query params to url
        markdown_content = re.sub(r'(https://[^)\s])+\?[^)\s]+', r'\1', markdown_content)
        
        lines_without_headers = [l for l in markdown_content.splitlines() if not l.startswith('#')]
        if not lines_without_headers:
            continue

        prefix = f'# {page_meta['title']}'
        page_chunks = []
        for chunk_idx, chunk_content in enumerate(split_page_by_size(markdown_content)):

            lines_without_headers = [l for l in chunk_content.splitlines() if not l.startswith('#')]
            if not lines_without_headers:
                continue
            # find hyperlinks 
            chunk_content, page_links, images_idx = get_urls(chunk_content)
            # add title to each chunk
            title = prefix + f' chunk_{chunk_idx}'
            
            chunk_content = (prefix + '\n' + chunk_content)
            chunk_filename = f'page_{page_meta['page_idx']}_chunk_{chunk_idx}.md'
            with open('chunks\\' + chunk_filename, mode='w', encoding='utf-8', errors='surrogatepass') as cf:
                cf.write(chunk_content)

            page_chunks.append(
                {
                    'chunk_data_filename': chunk_filename,
                    'page_links': page_links,
                    'images_idx': images_idx
                }
            )
        
        # how to go from page links to chunks ?
        page_meta['chunks'] = page_chunks
        # break
# Out:
# 100%|███████████████████████████████████████████████████████████| 1981/1981 [01:44<00:00, 18.97it/s]

# %%
with open('DMAS_CHUNK_META.json', 'w') as f:
    json.dump(flattened_document_meta, f, indent=4)

# %%
import pandas as pd
def measure(file):
    with open(file) as f:
        df = pd.DataFrame([l.strip().split() for l in f.readlines()])
    df[0] = df.iloc[:, 0].astype(int, copy=True)
    df.columns = ['size', 'file']
    return df

# %%
measure('lens.txt').describe()
# Out:
#               size
# count  3389.000000
# mean    147.429035
# std     178.426239
# min       5.000000
# 25%      31.000000
# 50%      84.000000
# 75%     176.000000
# max    1207.000000

# %%
measure('lens_new.txt').describe()
# Out:
#               size
# count  3014.000000
# mean    165.685800
# std     184.232041
# min       5.000000
# 25%      49.000000
# 50%      97.000000
# 75%     195.000000
# max    1234.000000
